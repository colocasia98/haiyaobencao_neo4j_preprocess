# %%
# 导入需求包
import openpyxl
import csv
import os
import time
from openpyxl import Workbook
import pandas as pd

# %%
# 如果导入需求包出现问题，运行这个模块。（需要等待一段时间）
! pip3 install openpyxl pandas
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple/
# Requirement already satisfied: openpyxl in c:\users\colocasia\anaconda3\lib\site-packages (3.0.9)
# Requirement already satisfied: pandas in c:\users\colocasia\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: et-xmlfile in c:\users\colocasia\anaconda3\lib\site-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\colocasia\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\colocasia\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\colocasia\anaconda3\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: six>=1.5 in c:\users\colocasia\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# 读取原始数据
wb = openpyxl.load_workbook(os.getcwd()+r"\haiyao_standard.xlsx")
ws = wb.active

# %%
def gen_item(raw_ws):
    """
    生成实体信息csv
    """
    types = []
    for type_cell in raw_ws[1]:
        type_ = type_cell.value
        types.append([type_, []])
        
    for line in raw_ws[2:raw_ws.max_row]:
        for i, cell in enumerate(line):
            values = cell.value
            if not values:
                continue
            values = values.replace("\n", "")
            values = values.replace(" ", "")
            values = values.replace("，", ",")
            values = values.replace("、", ",")
            values = values.replace(".", ",")
            values = values.replace("。", ",")
            values = values.strip()
            for value in values.split(','):
                if not value:
                    continue
                if value not in types[i][1]:
                    types[i][1].append(value)
                
    time_ = time.strftime("%m%d_%H%M%S", time.localtime()) 
    folder = str(time_)+'_items'
    for type_msg in types:
        type_ = type_msg[0]
        items = type_msg[1]
        df = pd.DataFrame({type_: items}) 
        print(df)
        if not os.path.exists(folder):
            os.makedirs(folder)
        df.to_csv(folder+'/'+type_+'_items.csv',encoding='utf_8_sig', index=False)

# %%
# 生成实体信息csv
gen_item(ws)
# Out:
#        药名
# 0      玉屑
# 1      车渠
# 2     金线矾
# 3    波斯白矾
# 4      金屑
# ..    ...
# 126   文林郎
# 127   无漏子
# 128   摩厨子
# 129   君迁子
# 130    师草
#
# [131 rows x 1 columns]
#     部
# 0  玉石
# 1   草
# 2   木
# 3   兽
# 4  虫鱼
# 5  果米
#         产地
# 0       昆仑
# 1       钟山
# 2       西国
# 3      波斯国
# 4      大秦国
# 5      大食国
# 6     蜀中雅州
# 7       南海
# 8      新罗国
# 9       东海
# 10     昆仑山
# 11      岭南
# 12      西海
# 13      安南
# 14     昆仑国
# 15      黔中
# 16      奚国
# 17      秦国
# 18    广南山谷
# 19    西戎诸地
# 20      剽地
# 21      广南
# 22      源州
# 23      西域
# 24      海南
# 25  东海及昆仑国
# 26      鄂州
# 27      岳州
# 28    南中八郡
# 29     新平县
# 30   岭南及诸海
# 31   西海波斯国
# 32    山东海水
# 33      广州
# 34      云南
# 35      交趾
# 36     卑占国
#    味
# 0  咸
# 1  酸
# 2  涩
# 3  甘
# 4  苦
# 5  辛
# 6  温
#     性
# 0   寒
# 1  大寒
# 2   温
# 3   平
# 4  微温
# 5  小温
# 6   冷
# 7  大温
# 8  微寒
#           毒
# 0         无
# 1         有
# 2  生者有毒熟者无毒
# 3       有小毒
# 4       有大毒
#     非药用功效
# 0    鬼气注忤
# 1    风邪鬼注
# 2      辟蛀
# 3      染发
# 4     辟蚊蚋
# 5     益颜色
# 6    鬼魅邪精
# 7   辟邪恶之气
# 8      辟恶
# 9      轻身
# 10     延年
# 11     长生
# 12   鬼疰心气
# 13     辟谷
# 14   心气鬼疰
# 15   令人光泽
# 16     不老
#      内科功效
# 0      补虚
# 1      除烦
# 2      解毒
# 3    重镇安神
# 4      止痢
# ..    ...
# 99   缓急止痛
# 100  润肺止咳
# 101  固精缩尿
# 102  清利头目
# 103    止咳
#
# [104 rows x 1 columns]
#    内科主治
# 0    消渴
# 1  时疫霍乱
# 2    虚劳
# 3    瘟疫
#        外科主治
# 0        痔疮
# 1        瘘病
# 2       风热疮
# 3        疥疮
# 4        癣病
# 5        牙痛
# 6        遗精
# 7       骨折病
# 8        漆疮
# 9       穿腮毒
# 10       痈病
# 11       疽病
# 12       风疹
# 13       疮疡
# 14      脚气病
# 15       牙痈
# 16       雀斑
# 17   男性前阴类病
# 18        癣
# 19     风赤疮疾
# 20  热毒壅聚头面证
# 21    肝经湿热证
# 22     疮疡类病
# 23       骨蚀
# 24       龋齿
# 25      面游风
# 26       瘾疹
# 27       肛瘘
# 28       盗汗
# 29       背疽
# 30       精冷
# 31       阳痿
# 32      月蚀疮
# 33       阴疮
# 34       甲疽
# 35      虫毒证
# 36      癞头疮
# 37       肥疮
# 38    筋骨损伤病
#       妇科主治
# 0       漏下
# 1       阴蚀
# 2      产后病
# 3   产后恶露不绝
# 4      儿枕痛
# 5     产后血晕
# 6    气血两虚证
# 7    乳晕部漏证
# 8       阴肿
# 9    胞宫虚寒证
# 10      梦交
# 11      难产
# 12      堕胎
# 13    产后腹痛
# 14  产后恶血冲心
# 15  产后恶血冲胃
# 16  产后恶血冲肺
# 17      癥瘕
# 18      癥积
#     儿科主治
# 0     疳病
# 1  小儿疫毒痢
# 2     水痘
# 3  初生儿呕吐
# 4     脱肛
# 5  髓虚骨弱证
# 6  脾胃不和证
# 7   小儿痘疹
# 8   小儿痫病

# %%
def gen_relation(raw_ws):
    """
    生成关系信息csv
    """
    relation_names = []
    
    drugs = []
    relations = []
    params = []
    
    tables = {}
    
    for cell in raw_ws[1]:
        relation_names.append(cell.value)
        tables[cell.value] = {
            "drugs": [],
            "relations": [],
            "params": [] 
        }
    print(relation_names)
        
    for line in raw_ws[2:raw_ws.max_row]:
        drug = line[0].value
        if not drug:
            break
        drug = drug.strip()
        for i, cell in enumerate(line):
            if i == 0:
                continue
                
            values = cell.value
            if not values:
                continue
            values = values.replace("\n", "")
            values = values.replace(" ", "")
            values = values.replace("，", ",")
            values = values.replace("、", ",")
            values = values.replace(".", ",")
            values = values.replace("。", ",")
            values = values.strip()
            for value in values.split(','):
                relation = relation_names[i]
                if not value:
                    continue
                tables[relation]["drugs"].append(drug)
                tables[relation]["relations"].append(relation_names[i]+"是")
                tables[relation]["params"].append(value)
                
    folder = str(time.strftime("%m%d_%H%M%S", time.localtime()))+"_relations"
    for relation in relation_names[1:]:
        table = tables[relation]
        df = pd.DataFrame({"药名": table["drugs"], 
                           "关系": table["relations"],
                           "属性": table["params"]}) 
        print(df)
        if not os.path.exists(folder):
            os.makedirs(folder)
        df.to_csv(folder+'/'+relation+'_relations.csv',encoding='utf_8_sig', index=False)

# %%
# 生成关系信息csv
gen_relation(ws)
# Out:
# ['药名', '部', '产地', '味', '性', '毒', '非药用功效', '内科功效', '内科主治', '外科主治', '妇科主治', '儿科主治']
#        药名  关系  属性
# 0      玉屑  部是  玉石
# 1      车渠  部是  玉石
# 2     金线矾  部是  玉石
# 3    波斯白矾  部是  玉石
# 4      金屑  部是  玉石
# ..    ...  ..  ..
# 126   文林郎  部是  果米
# 127   无漏子  部是  果米
# 128   摩厨子  部是  果米
# 129   君迁子  部是  果米
# 130    师草  部是  果米
#
# [131 rows x 3 columns]
#        药名   关系   属性
# 0      玉屑  产地是   昆仑
# 1      玉屑  产地是   钟山
# 2      车渠  产地是   西国
# 3     金线矾  产地是  波斯国
# 4    波斯白矾  产地是  大秦国
# ..    ...  ...  ...
# 107    橄榄  产地是   南海
# 108   海松子  产地是   云南
# 109   偏桃仁  产地是  卑占国
# 110   都角子  产地是   广南
# 111   摩厨子  产地是   西域
#
# [112 rows x 3 columns]
#       药名  关系 属性
# 0     玉屑  味是  咸
# 1    金线矾  味是  咸
# 2    金线矾  味是  酸
# 3    金线矾  味是  涩
# 4   波斯白矾  味是  酸
# ..   ...  .. ..
# 60    豆蔻  味是  辛
# 61    荔枝  味是  甘
# 62    荔枝  味是  酸
# 63    松子  味是  甘
# 64   文林郎  味是  酸
#
# [65 rows x 3 columns]
#       药名  关系  属性
# 0     玉屑  性是   寒
# 1     车渠  性是  大寒
# 2   波斯白矾  性是   温
# 3     金屑  性是   寒
# 4     银屑  性是  大寒
# ..   ...  ..  ..
# 68   蚺蛇胆  性是  大寒
# 69   海蚕沙  性是  大温
# 70    松子  性是  大温
# 71   文林郎  性是  微温
# 72   君迁子  性是  微寒
#
# [73 rows x 3 columns]
#        药名  关系        属性
# 0      玉屑  毒是         无
# 1      车渠  毒是         无
# 2     金线矾  毒是         有
# 3    波斯白矾  毒是         无
# 4      金屑  毒是  生者有毒熟者无毒
# 5      银屑  毒是         无
# 6      血竭  毒是         无
# 7      珊瑚  毒是         无
# 8      石蟹  毒是         无
# 9     草犀根  毒是         无
# 10  无风独摇草  毒是         无
# 11     海根  毒是         无
# 12    兜纳香  毒是         无
# 13    延胡索  毒是         无
# 14    肉豆蔻  毒是         无
# 15    零陵香  毒是         无
# 16    荜澄茄  毒是         无
# 17     茅香  毒是         无
# 18     仙茅  毒是       有小毒
# 19    白附子  毒是       有小毒
# 20     瓶香  毒是         无
# 21    钗子股  毒是         无
# 22    挈车香  毒是         无
# 23    冲洞根  毒是         无
# 24     沉香  毒是         无
# 25    降真香  毒是         无
# 26     藤黄  毒是         有
# 27    海红豆  毒是       有小毒
# 28    落雁木  毒是         无
# 29     莎木  毒是         无
# 30    栅木皮  毒是         无
# 31   无名木皮  毒是         无
# 32    无名子  毒是         无
# 33    奴会子  毒是         无
# 34    帛芦叶  毒是         无
# 35     槟榔  毒是         无
# 36     芜荑  毒是         无
# 37     龙脑  毒是         无
# 38    余甘子  毒是         无
# 39    毗梨勒  毒是         无
# 40     没药  毒是         无
# 41    海桐皮  毒是         无
# 42    都咸子  毒是         无
# 43    诃梨勒  毒是         无
# 44    苏方木  毒是         无
# 45    无食子  毒是         无
# 46    千金藤  毒是         无
# 47    栟榈木  毒是       有大毒
# 48     犀角  毒是         无
# 49    腽肭脐  毒是         无
# 50    鲛鱼皮  毒是         无
# 51     逐题  毒是         无
# 52    蚺蛇胆  毒是         有
# 53     蛤蚧  毒是         无
# 54    海蚕沙  毒是         无
# 55     松子  毒是         无
# 56    文林郎  毒是         无
# 57    君迁子  毒是         无
#      药名      关系     属性
# 0    海根  非药用功效是   鬼气注忤
# 1    阿魏  非药用功效是   风邪鬼注
# 2   延胡索  非药用功效是     辟蛀
# 3   荜澄茄  非药用功效是     染发
# 4   迷迭香  非药用功效是    辟蚊蚋
# 5    仙茅  非药用功效是    益颜色
# 6    瓶香  非药用功效是   鬼魅邪精
# 7   挈车香  非药用功效是     辟蛀
# 8   降真香  非药用功效是  辟邪恶之气
# 9    蜜香  非药用功效是     辟恶
# 10  余甘子  非药用功效是     轻身
# 11  余甘子  非药用功效是     延年
# 12  余甘子  非药用功效是     长生
# 13  必栗香  非药用功效是   鬼疰心气
# 14  千金藤  非药用功效是     轻身
# 15  桄榔子  非药用功效是     轻身
# 16  桄榔子  非药用功效是     辟谷
# 17   牡蛎  非药用功效是     轻身
# 18  鲛鱼皮  非药用功效是   心气鬼疰
# 19  海蚕沙  非药用功效是   令人光泽
# 20  海蚕沙  非药用功效是     轻身
# 21  海蚕沙  非药用功效是     延年
# 22  海蚕沙  非药用功效是     不老
# 23   松子  非药用功效是     轻身
# 24   松子  非药用功效是     延年
# 25   松子  非药用功效是     不老
# 26  君迁子  非药用功效是     轻身
#        药名     关系       属性
# 0      玉屑  内科功效是       补虚
# 1      玉屑  内科功效是       除烦
# 2      车渠  内科功效是       解毒
# 3      车渠  内科功效是     重镇安神
# 4    波斯白矾  内科功效是       解毒
# ..    ...    ...      ...
# 305   摩厨子  内科功效是       补血
# 306   君迁子  内科功效是     除烦止渴
# 307   君迁子  内科功效是  清心[热]安神
# 308    师草  内科功效是   温中[散寒]
# 309    师草  内科功效是       止呕
#
# [310 rows x 3 columns]
#        药名     关系    属性
# 0      玉屑  内科主治是    消渴
# 1      海根  内科主治是  时疫霍乱
# 2     风延母  内科主治是    消渴
# 3      蒟酱  内科主治是  时疫霍乱
# 4     零陵香  内科主治是    虚劳
# 5     艾蒳香  内科主治是    瘟疫
# 6      瓶香  内科主治是    瘟疫
# 7     挈车香  内科主治是  时疫霍乱
# 8      沉香  内科主治是  时疫霍乱
# 9     降真香  内科主治是    瘟疫
# 10    栅木皮  内科主治是  时疫霍乱
